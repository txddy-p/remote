# %%
#Question 1
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

t = np.linspace(0, 10, 200);
x = np.cos(4*t)
y = np.sin(4*t)

fig, (Re, Im) = plt.subplots(2,1)
fig.suptitle('Question 1')
Re.plot(t, x);
Re.set_ylabel('Re');Re.set_xlabel('t');

Im.plot(t, y);
Im.set_ylabel('Im');Im.set_xlabel('t');
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Question 2
import matplotlib.pyplot as plt
x = np.array([])
x = np.append(x,10)

for i in range(1,100):
    x = np.append(x,-0.90*x[i-1])
    pass

fig1, u = plt.subplots(1,1)
fig1.suptitle('Question 2')

u.set_xlabel("n (discrete time)")
u.set_ylabel("x[n]")
u.stem(range(100),x);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Question 3
import sympy as sp
v,g,t = sp.symbols('v g t')
f = v*t -(0.5*g*(t**2))
exp = f.subs([(g,9.8),(v,20)])

sp.plot(exp, (t,0,10), xlabel="t [s]", ylabel="s(t) [m]", title="Height vs time");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Question 4
t = sp.symbols('t')
acc = 0.3+sp.cos(t)

vt = sp.integrate(acc)-0.2 #velocity is the integral of acceleration
sp.plot(vt, (t,0,5), xlabel="t [s]", ylabel="v(t) [m/s]", title="Velocity vs time")

st = sp.integrate(vt)+1.1 #displacement is the integral of velocity
sp.plot(st, (t,0,5), xlabel="t [s]", ylabel="s(t) [m]", title="Distance vs time");
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
#Question 2 old

a = np.arange(100,dtype=float) #(0,100,dtype=float)
a[0] = 10

for i in range(1,100):
    a[i]=-0.9*a[i-1]
    
fig1, u = plt.subplots(1,1)
fig1.suptitle('Question 2')

#u.set_xlabel("n (discrete time)")
#u.set_ylabel("x[n]")
#u.stem(range(100),a);
#plt.stem(range(100),a)
plt.stem(x)
plt.ylabel("x[n]")
plt.xlabel("n (discrete time)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
